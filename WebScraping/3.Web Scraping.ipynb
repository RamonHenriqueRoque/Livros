# %% [markdown]
# #**Livro que utilizei como base:**
# - *Web Scraping com Python: coletando mais dados na web moderna, 2ª edição, Ryan Mitchell (O'Reilly).*
#
# O princípio desse notebook é estudar sobre Web Scraping, para isso, testarei exemplos que foram abordados no livro (mencionado acima), e no final de cada capítulo, farei um exemplo na prática em base do capítulo lido.

# %% [markdown]
# # **Capítulo 3 - Escrevendo Web Crawlers**

# %% [markdown]
# *Caso precise utilizar dados do Wikipedia, podemos utilizar seu API, no seguinte link.*
#
# https://www.mediawiki.org/wiki/API:Main_page

# %% [markdown]
# **Six degrees of Kevin Bacon**

# %%
# Coletar todos os links
from urllib.request import urlopen
from bs4 import BeautifulSoup

url= "https://pt.wikipedia.org/wiki/Kevin_Bacon"
html= urlopen(url)

bs= BeautifulSoup(html, "html.parser")

for link in bs.find_all("a"):
  if "href" in link.attrs:
    print(link.attrs["href"])
# Out:
# #content
# /wiki/Wikip%C3%A9dia:P%C3%A1gina_principal
# /wiki/Especial:Pesquisar
# /w/index.php?title=Especial:Criar_conta&returnto=Kevin+Bacon
# /w/index.php?title=Especial:Criar_conta&returnto=Kevin+Bacon
# /w/index.php?title=Especial:Entrar&returnto=Kevin+Bacon
# /wiki/Wikip%C3%A9dia:Boas-vindas
# /wiki/Especial:Minha_discuss%C3%A3o
# /wiki/Especial:Minhas_contribui%C3%A7%C3%B5es
# /wiki/Wikip%C3%A9dia:P%C3%A1gina_principal
# /wiki/Portal:Conte%C3%BAdo_destacado
# /wiki/Portal:Eventos_atuais
# /wiki/Wikip%C3%A9dia:Esplanada
# /wiki/Especial:Aleat%C3%B3ria
# /wiki/Portal:%C3%8Dndice
# /wiki/Wikip%C3%A9dia:Informe_um_erro
# /wiki/Wikip%C3%A9dia:Boas-vindas
# /wiki/Ajuda:P%C3%A1gina_principal
# /wiki/Ajuda:P%C3%A1gina_de_testes
# /wiki/Wikip%C3%A9dia:Portal_comunit%C3%A1rio
# /wiki/Especial:Mudan%C3%A7as_recentes
# /wiki/Wikip%C3%A9dia:Manuten%C3%A7%C3%A3o
# /wiki/Ajuda:Guia_de_edi%C3%A7%C3%A3o/Como_come%C3%A7ar_uma_p%C3%A1gina
# /wiki/Especial:P%C3%A1ginas_novas
# /wiki/Wikip%C3%A9dia:Contato
# //donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=20120521SB001&uselang=pt
# /wiki/Especial:P%C3%A1ginas_afluentes/Kevin_Bacon
# /wiki/Especial:Altera%C3%A7%C3%B5es_relacionadas/Kevin_Bacon
# /wiki/Wikipedia:Carregar_ficheiro
# /wiki/Especial:P%C3%A1ginas_especiais
# /w/index.php?title=Kevin_Bacon&oldid=61557061
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Especial:Citar&page=Kevin_Bacon&id=61557061&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Especial:Livro&bookcmd=book_creator&referer=Kevin+Bacon
# /w/index.php?title=Especial:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# /wiki/Kevin_Bacon
# /wiki/Discuss%C3%A3o:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&veaction=edit
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://en.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Ficheiro:Kevin_Bacon_SDCC_2014.jpg
# /wiki/8_de_julho#Nascimentos
# /wiki/1958
# /wiki/Filad%C3%A9lfia
# /wiki/Povo_dos_Estados_Unidos
# /wiki/Ator
# /wiki/Kyra_Sedgwick
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Golden_Globe_Award_para_Melhor_Ator_(miniss%C3%A9rie_ou_filme)_em_televis%C3%A3o
# /wiki/2010
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_elenco_em_cinema
# /wiki/1996
# /wiki/Apollo_13_(filme)
# /wiki/Pr%C3%AAmios_Critics%27_Choice_Movie
# /wiki/Pr%C3%A9mio_Critics_Choice_de_melhor_ator_em_cinema
# /wiki/Murder_in_the_First
# /wiki/Filad%C3%A9lfia
# /wiki/8_de_julho
# /wiki/1958
# /wiki/Ator
# /wiki/Povo_dos_Estados_Unidos
# /wiki/Animal_House_(filme)
# /wiki/Footloose_(1984)
# /w/index.php?title=Six_Degrees_of_Kevin_Bacon&action=edit&redlink=1
# /wiki/Teoria_dos_seis_graus_de_separa%C3%A7%C3%A3o
# #cite_note-1
# #cite_note-2
# #Biografia
# #Início_da_carreira
# #Estrelato_e_decadência
# #Vida_pessoal
# #Sucessos_isolados
# #Reformulação_da_carreira
# #Novo_estrelato
# #Carreira_musical
# #Filmes_polêmicos
# #Filmografia
# #Cinema
# #Televisão
# #Premiações
# #Referências
# #Ligações_externas
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=1
# /w/index.php?title=Kevin_Bacon&action=edit&section=1
# #cite_note-cinemapassion-3
# /wiki/Nova_Iorque
# /wiki/Teatro_Broadway
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=2
# /w/index.php?title=Kevin_Bacon&action=edit&section=2
# /wiki/Animal_House_(filme)
# /wiki/John_Belushi
# /wiki/John_Landis
# /wiki/Los_Angeles
# /wiki/Teatro
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=3
# /w/index.php?title=Kevin_Bacon&action=edit&section=3
# /wiki/Sexta-Feira_13_(1980)
# /wiki/Diner
# /wiki/Barry_Levinson
# /wiki/Steve_Guttenberg
# /wiki/Mickey_Rourke
# /wiki/Ellen_Barkin
# /wiki/Ficheiro:Kevin_Bacon.jpg
# /wiki/Ficheiro:Kevin_Bacon.jpg
# /wiki/Footloose_(1984)
# /wiki/D%C3%A9cada_de_1980
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=4
# /w/index.php?title=Kevin_Bacon&action=edit&section=4
# /wiki/Kyra_Sedgwick
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=5
# /w/index.php?title=Kevin_Bacon&action=edit&section=5
# /wiki/Filme_B
# /wiki/Tremors
# /wiki/Kiefer_Sutherland
# /wiki/William_Baldwin_(ator)
# /wiki/Julia_Roberts
# /wiki/Linha_Mortal
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=6
# /w/index.php?title=Kevin_Bacon&action=edit&section=6
# /wiki/Hollywood
# /wiki/JFK_(filme)
# /wiki/Oliver_Stone
# /wiki/A_Few_Good_Men
# /wiki/Rob_Reiner
# /wiki/Saundra_Santiago
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=7
# /w/index.php?title=Kevin_Bacon&action=edit&section=7
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First
# /wiki/Apollo_13_(filme)
# /wiki/Sleepers
# /wiki/Wild_Things
# /wiki/Matt_Dillon
# /wiki/Neve_Campbell
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=8
# /w/index.php?title=Kevin_Bacon&action=edit&section=8
# /wiki/D%C3%A9cada_de_1990
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=9
# /w/index.php?title=Kevin_Bacon&action=edit&section=9
# /wiki/The_Woodsman
# /wiki/Ped%C3%B3filo
# /wiki/Where_the_Truth_Lies
# /wiki/Homossexual
# /w/index.php?title=Taking_Chance&action=edit&redlink=1
# /wiki/HBO
# /wiki/Guerra_do_Golfo
# /wiki/Guerra_do_Iraque
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Screen_Actors_Guild_Award
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=10
# /w/index.php?title=Kevin_Bacon&action=edit&section=10
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=11
# /w/index.php?title=Kevin_Bacon&action=edit&section=11
# /w/index.php?title=Hist%C3%B3ria_De_Uma_Garota&action=edit&redlink=1
# /wiki/Patriots_Day
# /wiki/Jayne_Mansfield%27s_Car
# #cite_note-4
# /wiki/X-Men:_First_Class
# /w/index.php?title=Elephant_White&action=edit&redlink=1
# /w/index.php?title=Super_(filme)&action=edit&redlink=1
# /wiki/My_One_and_Only
# /wiki/Frost/Nixon
# /wiki/The_Air_I_Breathe
# /w/index.php?title=Rails%26Ties&action=edit&redlink=1
# /wiki/Death_Sentence
# /wiki/Where_the_Truth_Lies
# /wiki/Beauty_Shop
# /wiki/Loverboy_(2005)
# /wiki/The_Woodsman
# /wiki/In_the_Cut
# /wiki/Mystic_River
# /wiki/Trapped_(2002)
# /wiki/Novocaine
# /wiki/Hollow_Man
# /wiki/My_Dog_Skip
# /wiki/Stir_of_Echoes
# /wiki/Wild_Things
# /wiki/Digging_to_China
# /wiki/Telling_Lies_in_America
# /wiki/Picture_Perfect
# /wiki/Sleepers
# /wiki/Balto_(filme)
# /wiki/Apollo_13_(filme)
# /wiki/Murder_in_the_First
# /wiki/The_River_Wild
# /w/index.php?title=The_Air_Up_There&action=edit&redlink=1
# /wiki/A_Few_Good_Men
# /wiki/JFK_(filme)
# /wiki/He_Said,_She_Said
# /w/index.php?title=Queens_Logic&action=edit&redlink=1
# /w/index.php?title=Pyrates&action=edit&redlink=1
# /wiki/Flatliners_(1990)
# /wiki/Tremors
# /wiki/The_Big_Picture
# /wiki/Criminal_Law
# /wiki/She%27s_Having_a_Baby
# /wiki/Planes,_Trains_%26_Automobiles
# /w/index.php?title=End_of_the_Line&action=edit&redlink=1
# /wiki/White_Water_Summer
# /wiki/Quicksilver_(filme)
# /wiki/Footloose_(1984)
# /w/index.php?title=Enourmous_Changes_at_the_Last_Minute&action=edit&redlink=1
# /wiki/Diner_(filme)
# /wiki/Only_When_I_Laugh
# /wiki/Sexta-Feira_13_(1980)
# /w/index.php?title=Hero_at_Large&action=edit&redlink=1
# /wiki/Starting_Over
# /wiki/Animal_House_(filme)
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=12
# /w/index.php?title=Kevin_Bacon&action=edit&section=12
# /wiki/The_Following
# /w/index.php?title=Taking_Chance&action=edit&redlink=1
# /wiki/Chuck_(s%C3%A9rie)
# /wiki/Supernatural_(s%C3%A9rie)
# /wiki/Will_%26_Grace
# /w/index.php?title=Cavedweller&action=edit&redlink=1
# /w/index.php?title=Lemon_Sky&action=edit&redlink=1
# /wiki/The_Demon_Murder_Case
# /wiki/Once_Upon_a_Time_(6.%C2%AA_temporada)
# /wiki/Once_Upon_a_Time_(6.%C2%AA_temporada)
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=13
# /w/index.php?title=Kevin_Bacon&action=edit&section=13
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Independent_Spirit_Awards
# /wiki/Satellite_Awards
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# #cite_ref-1
# https://jornaldoempreendedor.com.br/empreendedorismo-na-web/novidades-pela-net/teoria-dos-graus-de-kevin-bacon-e-aplicada-a-todos-os-sites-da-webz/
# #cite_ref-2
# https://revistamonet.globo.com/Celebridades/noticia/2019/08/kevin-bacon-diz-ter-ficado-ofendido-com-brincadeira-sobre-seis-graus-de-separacao.html
# #cite_ref-cinemapassion_3-0
# http://www.cinemapassion.com/filmographie-acteur-Kevin%20BACON-19.html
# #cite_ref-4
# http://cinema.uol.com.br/album/jayne-mansfields-car_album.htm
# /wiki/Universo_Online
# /w/index.php?title=Kevin_Bacon&veaction=edit&section=14
# /w/index.php?title=Kevin_Bacon&action=edit&section=14
# /wiki/Ficheiro:Commons-logo.svg
# https://commons.wikimedia.org/wiki/P%C3%A1gina_principal
# https://commons.wikimedia.org/w/index.php?title=Kevin+Bacon&uselang=pt
# /wiki/Predefini%C3%A7%C3%A3o:Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_filme_para_televis%C3%A3o
# /w/index.php?title=Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_filme_para_televis%C3%A3o&action=edit&redlink=1
# https://pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_filme_para_televis%C3%A3o&action=edit
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /w/index.php?title=Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:SAG_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme&action=edit&redlink=1
# https://pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:SAG_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme&action=edit
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_1996%E2%80%932000
# /w/index.php?title=Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:SAG_de_melhor_elenco_em_cinema_1996%E2%80%932000&action=edit&redlink=1
# https://pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_1996%E2%80%932000&action=edit
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_para_melhor_elenco_em_cinema
# /wiki/Apollo_13_(filme)
# /wiki/Tom_Hanks
# /wiki/Ed_Harris
# /wiki/Bill_Paxton
# /wiki/Kathleen_Quinlan
# /wiki/Gary_Sinise
# /wiki/The_Birdcage
# /wiki/Hank_Azaria
# /wiki/Christine_Baranski
# /wiki/Dan_Futterman
# /wiki/Gene_Hackman
# /wiki/Nathan_Lane
# /wiki/Dianne_Wiest
# /wiki/Robin_Williams
# /wiki/Ou_Tudo_ou_Nada
# /wiki/Mark_Addy
# /w/index.php?title=Paul_Barber&action=edit&redlink=1
# /wiki/Robert_Carlyle
# /w/index.php?title=Deirdre_Costello&action=edit&redlink=1
# /w/index.php?title=Steve_Huison&action=edit&redlink=1
# /w/index.php?title=Bruce_Jones&action=edit&redlink=1
# /w/index.php?title=Lesley_Sharp&action=edit&redlink=1
# /w/index.php?title=William_Snape&action=edit&redlink=1
# /w/index.php?title=Hugo_Speer&action=edit&redlink=1
# /wiki/Tom_Wilkinson
# /w/index.php?title=Emily_Woof&action=edit&redlink=1
# /wiki/Shakespeare_in_Love
# /wiki/Ben_Affleck
# /w/index.php?title=Simon_Callow&action=edit&redlink=1
# /wiki/Jim_Carter
# /w/index.php?title=Martin_Clunes&action=edit&redlink=1
# /wiki/Judi_Dench
# /wiki/Joseph_Fiennes
# /wiki/Colin_Firth
# /wiki/Gwyneth_Paltrow
# /wiki/Geoffrey_Rush
# /w/index.php?title=Anthony_Sher&action=edit&redlink=1
# /wiki/Imelda_Staunton
# /wiki/Beleza_Americana
# /wiki/Annette_Bening
# /wiki/Wes_Bentley
# /wiki/Thora_Birch
# /wiki/Chris_Cooper
# /wiki/Peter_Gallagher
# /wiki/Allison_Janney
# /wiki/Kevin_Spacey
# /wiki/Mena_Suvari
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_1996%E2%80%932000
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_2001%E2%80%932010
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_2011%E2%80%932020
# /wiki/Predefini%C3%A7%C3%A3o:SAG_de_melhor_elenco_em_cinema_2021%E2%80%932030
# /wiki/Predefini%C3%A7%C3%A3o:Critics%27_Choice_de_Melhor_Ator_em_Cinema
# /w/index.php?title=Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:Critics%27_Choice_de_Melhor_Ator_em_Cinema&action=edit&redlink=1
# https://pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:Critics%27_Choice_de_Melhor_Ator_em_Cinema&action=edit
# /wiki/Pr%C3%AAmios_Critics%27_Choice_Movie
# /wiki/Pr%C3%A9mio_Critics_Choice_de_melhor_ator_em_cinema
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Ficheiro:Pictograma_Arte_rupestre.PNG
# /wiki/Portal:Arte
# /wiki/Ficheiro:Emoji_u1f4fd.svg
# /wiki/Portal:Cinema
# /wiki/Ficheiro:Crystal_Clear_app_Login_Manager.png
# /wiki/Portal:Biografias
# /wiki/Ajuda:Controle_de_autoridade
# https://www.wikidata.org/wiki/Wikidata:Main_Page
# https://www.wikidata.org/wiki/Q3454165
# //www.worldcat.org/identities/containsVIAFID/39570812
# /wiki/Base_Virtual_Internacional_de_Autoridade
# https://viaf.org/viaf/39570812/
# /wiki/Bibsys
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# /wiki/Biblioteca_Nacional_da_Espanha
# https://datos.bne.es/resource/XX1298810
# /wiki/Biblioteca_Nacional_da_Fran%C3%A7a
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# /wiki/Discogs
# https://www.discogs.com/artist/956139
# /wiki/Faceted_Application_of_Subject_Terminology
# https://experimental.worldcat.org/fast/242183/
# /wiki/Gemeinsame_Normdatei
# https://d-nb.info/gnd/124109659
# /wiki/Internet_Broadway_Database
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/International_Standard_Name_Identifier
# https://isni.oclc.org/xslt/DB=1.2/CMD?ACT=SRCH&IKT=8006&TRM=ISN%3A0000000121291300
# /wiki/N%C3%BAmero_de_controle_da_Biblioteca_do_Congresso
# https://id.loc.gov/authorities/n88034930
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://www.munzinger.de/search/go/document.jsp?id=00000023526
# /wiki/Biblioteca_Nacional_da_Rep%C3%BAblica_Checa
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279
# /wiki/Biblioteca_Nacional_da_Austr%C3%A1lia
# https://librariesaustralia.nla.gov.au/search/display?dbid=auth&id=36021861
# /wiki/NNDB
# https://www.nndb.com/people/717/000022651/
# /wiki/Biblioteca_Real_dos_Pa%C3%ADses_Baixos
# https://data.bibliotheken.nl/doc/thes/p147880998
# https://wikidata-externalid-url.toolforge.org/?p=1207&url_prefix=http://nukat.edu.pl/aut/&id=n2008131085
# https://openmlol.it/autore/221967
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/Sistema_Universit%C3%A1rio_de_Documenta%C3%A7%C3%A3o
# https://www.idref.fr/084292652
# /wiki/TV.com
# https://web.archive.org/web/20080201113148/http://www.tv.com/people/kevin-bacon/
# /wiki/WikiTree
# https://www.wikitree.com/wiki/Bacon-2568
# /wiki/IMDb
# https://wikidata-externalid-url.toolforge.org/?p=345&url_prefix=https://www.imdb.com/&id=nm0000102
# /wiki/Biblioteca_Nacional_de_Israel
# http://uli.nli.org.il/F/?func=direct&local_base=nlx10&doc_number=002168993
# /wiki/AllMovie
# https://www.allmovie.com/artist/p3164
# /wiki/AlloCin%C3%A9
# https://www.allocine.fr/personne/fichepersonne_gen_cpersonne=2130.html?nopub=1
# /wiki/Box_Office_Mojo
# https://web.archive.org/*/https://www.boxofficemojo.com/people/chart/?id=kevinbacon.htm
# https://d23.com/disney-a-to-z/bacon-kevin/
# https://pt.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=61557061
# /wiki/Especial:Categorias
# /wiki/Categoria:Nascidos_em_1958
# /wiki/Categoria:Atores_dos_Estados_Unidos
# /wiki/Categoria:Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Categoria:Vencedores_do_Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Categoria:Vencedores_do_Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_elenco_em_filme
# /wiki/Categoria:Cal%C3%A7ada_da_Fama_de_Hollywood
# /wiki/Categoria:Naturais_de_Filad%C3%A9lfia_(Pensilv%C3%A2nia)
# /wiki/Categoria:Critics%27_Choice_de_melhor_ator_em_cinema
# /wiki/Categoria:Pessoas_vivas
# /wiki/Categoria:!Artigos_destacados_na_Wikip%C3%A9dia_em_franc%C3%AAs
# /wiki/Categoria:!Imagem_local_id%C3%AAntica_%C3%A0_do_Wikidata
# https://creativecommons.org/licenses/by-sa/3.0/deed.pt
# https://foundation.wikimedia.org/wiki/Condições_de_Uso
# https://meta.wikimedia.org/wiki/Privacy_policy/pt-br
# /wiki/Wikip%C3%A9dia:Sobre
# /wiki/Wikip%C3%A9dia:Aviso_geral
# //pt.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/pt.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
# Coletar todos os links sem os links inuteis
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

url= "https://pt.wikipedia.org/wiki/Kevin_Bacon"
html= urlopen(url)

bs= BeautifulSoup(html, "html.parser")
objeto_analise= bs.find("div", {"id":"bodyContent"}).find_all("a", href=re.compile("^(/wiki/)((?!:).)*$"))

for link in objeto_analise:
  if "href" in link.attrs:
    print(link.attrs["href"])
# Out:
# /wiki/8_de_julho#Nascimentos
# /wiki/1958
# /wiki/Filad%C3%A9lfia
# /wiki/Povo_dos_Estados_Unidos
# /wiki/Ator
# /wiki/Kyra_Sedgwick
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Golden_Globe_Award_para_Melhor_Ator_(miniss%C3%A9rie_ou_filme)_em_televis%C3%A3o
# /wiki/2010
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_elenco_em_cinema
# /wiki/1996
# /wiki/Apollo_13_(filme)
# /wiki/Pr%C3%AAmios_Critics%27_Choice_Movie
# /wiki/Pr%C3%A9mio_Critics_Choice_de_melhor_ator_em_cinema
# /wiki/Murder_in_the_First
# /wiki/Filad%C3%A9lfia
# /wiki/8_de_julho
# /wiki/1958
# /wiki/Ator
# /wiki/Povo_dos_Estados_Unidos
# /wiki/Animal_House_(filme)
# /wiki/Footloose_(1984)
# /wiki/Teoria_dos_seis_graus_de_separa%C3%A7%C3%A3o
# /wiki/Nova_Iorque
# /wiki/Teatro_Broadway
# /wiki/Animal_House_(filme)
# /wiki/John_Belushi
# /wiki/John_Landis
# /wiki/Los_Angeles
# /wiki/Teatro
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Sexta-Feira_13_(1980)
# /wiki/Diner
# /wiki/Barry_Levinson
# /wiki/Steve_Guttenberg
# /wiki/Mickey_Rourke
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984)
# /wiki/D%C3%A9cada_de_1980
# /wiki/Kyra_Sedgwick
# /wiki/Filme_B
# /wiki/Tremors
# /wiki/Kiefer_Sutherland
# /wiki/William_Baldwin_(ator)
# /wiki/Julia_Roberts
# /wiki/Linha_Mortal
# /wiki/Hollywood
# /wiki/JFK_(filme)
# /wiki/Oliver_Stone
# /wiki/A_Few_Good_Men
# /wiki/Rob_Reiner
# /wiki/Saundra_Santiago
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First
# /wiki/Apollo_13_(filme)
# /wiki/Sleepers
# /wiki/Wild_Things
# /wiki/Matt_Dillon
# /wiki/Neve_Campbell
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/D%C3%A9cada_de_1990
# /wiki/The_Woodsman
# /wiki/Ped%C3%B3filo
# /wiki/Where_the_Truth_Lies
# /wiki/Homossexual
# /wiki/HBO
# /wiki/Guerra_do_Golfo
# /wiki/Guerra_do_Iraque
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Screen_Actors_Guild_Award
# /wiki/Patriots_Day
# /wiki/Jayne_Mansfield%27s_Car
# /wiki/My_One_and_Only
# /wiki/Frost/Nixon
# /wiki/The_Air_I_Breathe
# /wiki/Death_Sentence
# /wiki/Where_the_Truth_Lies
# /wiki/Beauty_Shop
# /wiki/Loverboy_(2005)
# /wiki/The_Woodsman
# /wiki/In_the_Cut
# /wiki/Mystic_River
# /wiki/Trapped_(2002)
# /wiki/Novocaine
# /wiki/Hollow_Man
# /wiki/My_Dog_Skip
# /wiki/Stir_of_Echoes
# /wiki/Wild_Things
# /wiki/Digging_to_China
# /wiki/Telling_Lies_in_America
# /wiki/Picture_Perfect
# /wiki/Sleepers
# /wiki/Balto_(filme)
# /wiki/Apollo_13_(filme)
# /wiki/Murder_in_the_First
# /wiki/The_River_Wild
# /wiki/A_Few_Good_Men
# /wiki/JFK_(filme)
# /wiki/He_Said,_She_Said
# /wiki/Flatliners_(1990)
# /wiki/Tremors
# /wiki/The_Big_Picture
# /wiki/Criminal_Law
# /wiki/She%27s_Having_a_Baby
# /wiki/Planes,_Trains_%26_Automobiles
# /wiki/White_Water_Summer
# /wiki/Quicksilver_(filme)
# /wiki/Footloose_(1984)
# /wiki/Diner_(filme)
# /wiki/Only_When_I_Laugh
# /wiki/Sexta-Feira_13_(1980)
# /wiki/Starting_Over
# /wiki/Animal_House_(filme)
# /wiki/The_Following
# /wiki/Chuck_(s%C3%A9rie)
# /wiki/Supernatural_(s%C3%A9rie)
# /wiki/Will_%26_Grace
# /wiki/The_Demon_Murder_Case
# /wiki/Once_Upon_a_Time_(6.%C2%AA_temporada)
# /wiki/Once_Upon_a_Time_(6.%C2%AA_temporada)
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Independent_Spirit_Awards
# /wiki/Satellite_Awards
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Universo_Online
# /wiki/Pr%C3%AAmios_Globo_de_Ouro
# /wiki/Globo_de_Ouro_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_de_melhor_ator_em_miniss%C3%A9rie_ou_telefilme
# /wiki/Ra%C3%BAl_Juli%C3%A1
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Pr%C3%A9mios_Screen_Actors_Guild
# /wiki/Pr%C3%A9mio_Screen_Actors_Guild_para_melhor_elenco_em_cinema
# /wiki/Apollo_13_(filme)
# /wiki/Tom_Hanks
# /wiki/Ed_Harris
# /wiki/Bill_Paxton
# /wiki/Kathleen_Quinlan
# /wiki/Gary_Sinise
# /wiki/The_Birdcage
# /wiki/Hank_Azaria
# /wiki/Christine_Baranski
# /wiki/Dan_Futterman
# /wiki/Gene_Hackman
# /wiki/Nathan_Lane
# /wiki/Dianne_Wiest
# /wiki/Robin_Williams
# /wiki/Ou_Tudo_ou_Nada
# /wiki/Mark_Addy
# /wiki/Robert_Carlyle
# /wiki/Tom_Wilkinson
# /wiki/Shakespeare_in_Love
# /wiki/Ben_Affleck
# /wiki/Jim_Carter
# /wiki/Judi_Dench
# /wiki/Joseph_Fiennes
# /wiki/Colin_Firth
# /wiki/Gwyneth_Paltrow
# /wiki/Geoffrey_Rush
# /wiki/Imelda_Staunton
# /wiki/Beleza_Americana
# /wiki/Annette_Bening
# /wiki/Wes_Bentley
# /wiki/Thora_Birch
# /wiki/Chris_Cooper
# /wiki/Peter_Gallagher
# /wiki/Allison_Janney
# /wiki/Kevin_Spacey
# /wiki/Mena_Suvari
# /wiki/Pr%C3%AAmios_Critics%27_Choice_Movie
# /wiki/Pr%C3%A9mio_Critics_Choice_de_melhor_ator_em_cinema
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Base_Virtual_Internacional_de_Autoridade
# /wiki/Bibsys
# /wiki/Biblioteca_Nacional_da_Espanha
# /wiki/Biblioteca_Nacional_da_Fran%C3%A7a
# /wiki/Discogs
# /wiki/Faceted_Application_of_Subject_Terminology
# /wiki/Gemeinsame_Normdatei
# /wiki/Internet_Broadway_Database
# /wiki/International_Standard_Name_Identifier
# /wiki/N%C3%BAmero_de_controle_da_Biblioteca_do_Congresso
# /wiki/MusicBrainz
# /wiki/Biblioteca_Nacional_da_Rep%C3%BAblica_Checa
# /wiki/Biblioteca_Nacional_da_Austr%C3%A1lia
# /wiki/NNDB
# /wiki/Biblioteca_Real_dos_Pa%C3%ADses_Baixos
# /wiki/Sistema_Universit%C3%A1rio_de_Documenta%C3%A7%C3%A3o
# /wiki/TV.com
# /wiki/WikiTree
# /wiki/IMDb
# /wiki/Biblioteca_Nacional_de_Israel
# /wiki/AllMovie
# /wiki/AlloCin%C3%A9
# /wiki/Box_Office_Mojo

# %%
# Six Degrees
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

# Garante que todas as vezes que rodarmos seja diferentes
random.seed(datetime.datetime.now())

# Conseguir todos os links do url
def conseguir_links(url):
  html= urlopen("http://en.wikipedia.org{}".format(url))
  bs= BeautifulSoup(html, "html.parser")
  objeto_analise= bs.find("div", {"id":"bodyContent"}).find_all("a", href=re.compile("^(/wiki/)((?!:).)*$"))
  return(objeto_analise)

# Começo do url
links= conseguir_links("/wiki/Kevin_Bacon")
cont= 0

# Estrutura de repetição para pesquisar a nova pagina de forma aleatoria
while len(links) > 0:
  novo_url= links[random.randint(0, len(links)-1)].attrs["href"]
  print(novo_url)
  links= conseguir_links(novo_url)
  cont += 1

  # Parada
  if cont == 10:
    break
# Out:
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Candice_Bergen
# /wiki/Oliver%27s_Story
# /wiki/Tagline
# /wiki/Jingle
# /wiki/Lyrics
# /wiki/Singing_in_the_Spirit
# /wiki/Solo_(music)
# /wiki/String_octet
# /wiki/Jazz_quartet

# %% [markdown]
# *Utilidades*
#
# - Podemos passar todos os links para conseguirmos mapear um site.
# - E após mapeamos o site, podemos fazer uma coleta de dados.

# %% [markdown]
# *recursão*
#
# - Python tem um limite default para recursão igual a 1000. Tomar cuidado

# %%
# Para evitarmos de passarmos em site repetidos.

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# Conseguir todos os links do url
paginas_rastreadas= set()
cont = 0
def conseguir_links(url):
  global paginas_rastreadas                   # não conseguia

  html= urlopen("http://en.wikipedia.org{}".format(url))
  bs= BeautifulSoup(html, "html.parser")
  objeto_analise= bs.find_all("a", href=re.compile("^(/wiki/)((?!:).)*$"))

  for link in objeto_analise:
    if "href" in link.attrs:
      if link.attrs["href"] not in paginas_rastreadas:
        nova_url= link.attrs["href"]
        print(nova_url)

        paginas_rastreadas.add(nova_url)
        conseguir_links(nova_url)

conseguir_links("/wiki/Kevin_Bacon")
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Kevin_Bacon
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Philly_(disambiguation)
# /wiki/Philadelphia
# /wiki/Philadelphia_(disambiguation)
# /wiki/Philadelphia_County,_Pennsylvania
# /wiki/Consolidated_city-county
# /wiki/United_States#Government_and_politics
# /wiki/Americas
# /wiki/America_(disambiguation)
# /wiki/America
# /wiki/US_(disambiguation)
# /wiki/United_States_of_America
# /wiki/USA_(disambiguation)
# /wiki/USA
# /wiki/The_United_States_of_America_(disambiguation)
# /wiki/The_United_States_of_America
# /wiki/United_States_(disambiguation)
# /wiki/United_States
# /wiki/Geographic_coordinate_system
# /wiki/Geodesy
# /wiki/Geodetic_(disambiguation)
# /wiki/Geodetic_Hills
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3258c21541db> in <module>()
#      24         conseguir_links(nova_url)
#      25
# ---> 26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      22
#      23         paginas_rastreadas.add(nova_url)
# ---> 24         conseguir_links(nova_url)
#      25
#      26 conseguir_links("/wiki/Kevin_Bacon")
#
# <ipython-input-4-3258c21541db> in conseguir_links(url)
#      11   global paginas_rastreadas                   # não conseguia
#      12
# ---> 13   html= urlopen("http://en.wikipedia.org{}".format(url))
#      14   bs= BeautifulSoup(html, "html.parser")
#      15   objeto_analise= bs.find_all("a", href=re.compile("^(/wiki/)((?!:).)*$"))
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             try:
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1279                 encode_chunked=False):
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#    1283     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1325             # default charset of iso-8859-1.
#    1326             body = _encode(body, 'body')
# -> 1327         self.endheaders(body, encode_chunked=encode_chunked)
#    1328
#    1329     def getresponse(self):
#
# /usr/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1274         else:
#    1275             raise CannotSendHeader()
# -> 1276         self._send_output(message_body, encode_chunked=encode_chunked)
#    1277
#    1278     def request(self, method, url, body=None, headers={}, *,
#
# /usr/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1034         msg = b"\r\n".join(self._buffer)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#    1038         if message_body is not None:
#
# /usr/lib/python3.7/http/client.py in send(self, data)
#     974         if self.sock is None:
#     975             if self.auto_open:
# --> 976                 self.connect()
#     977             else:
#     978                 raise NotConnected()
#
# /usr/lib/python3.7/http/client.py in connect(self)
#    1449
#    1450             self.sock = self._context.wrap_socket(self.sock,
# -> 1451                                                   server_hostname=server_hostname)
#    1452
#    1453     __all__.append("HTTPSConnection")
#
# /usr/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# /usr/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# /usr/lib/python3.7/ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# **O erro acima é porque eu parei o código de rodar para não ser infinito**

# %% [markdown]
# *Os demais exemplos do livro*
#
# - Randomizar os pulos de um site para outro link de outro site (externo).
# - Obter os links externo e interno.

# %% [markdown]
# #**Meu exemplo para praticar**
# - Objetivo é partir de um link do wikipedia e pegar o link e o titulo dos outros links.

# %%
# !pip install prettytable

# %%
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
from bs4 import BeautifulSoup
from prettytable import PrettyTable
import re

def verificar_coneccao(url):
  try:
    html= urlopen("http://en.wikipedia.org{}".format(url))
    return(conseguir_titulo(html))
  
  except HTTPError as e:
    return("URL incorreto.")
  
  except URLError as e:
    return("Servidor indisponivel.")

def conseguir_titulo(html):
  try:
    bs= BeautifulSoup(html.read(), "lxml")
    return(bs.title.get_text())
  
  except AttributeError as e:
    return("Erro")

def conseguir_links(url):
  html= urlopen("http://en.wikipedia.org{}".format(url))
  bs= BeautifulSoup(html, "html.parser")
  objeto_analise= bs.find_all("a", href=re.compile("^(/wiki/)((?!:).)*$"))

  estrutura_tabela= PrettyTable()
  estrutura_tabela.field_names= ["Titulo", "Link"]

  for link in objeto_analise:
    if "href" in link.attrs:
      nova_url= link.attrs["href"]
      estrutura_tabela.add_row([verificar_coneccao(nova_url),nova_url])

  print(estrutura_tabela)

url= "/wiki/Xadrez"
conseguir_links(url)
# Out:
# +----------------------------------------------------------------------+------------------------------------------------------------------------+
# |                                Titulo                                |                                  Link                                  |
# +----------------------------------------------------------------------+------------------------------------------------------------------------+
# |                  Chess (disambiguation) - Wikipedia                  |                      /wiki/Chess_(disambiguation)                      |
# |                    Staunton chess set - Wikipedia                    |                        /wiki/Staunton_chess_set                        |
# |                       King (chess) - Wikipedia                       |                           /wiki/King_(chess)                           |
# |                       Rook (chess) - Wikipedia                       |                           /wiki/Rook_(chess)                           |
# |                      Queen (chess) - Wikipedia                       |                          /wiki/Queen_(chess)                           |
# |                       Pawn (chess) - Wikipedia                       |                           /wiki/Pawn_(chess)                           |
# |                      Knight (chess) - Wikipedia                      |                          /wiki/Knight_(chess)                          |
# |                      Bishop (chess) - Wikipedia                      |                          /wiki/Bishop_(chess)                          |
# |                        Board game - Wikipedia                        |                            /wiki/Board_game                            |
# |                  Abstract strategy game - Wikipedia                  |                      /wiki/Abstract_strategy_game                      |
# |                        Mind sport - Wikipedia                        |                            /wiki/Mind_sport                            |
# |                        Fast chess - Wikipedia                        |                            /wiki/Fast_chess                            |
# |                      Chess strategy - Wikipedia                      |                          /wiki/Chess_strategy                          |
# |                       Chess tactic - Wikipedia                       |                           /wiki/Chess_tactic                           |
# |                        Board game - Wikipedia                        |                            /wiki/Board_game                            |
# |                      Player (game) - Wikipedia                       |                          /wiki/Player_(game)                           |
# |                     Southern Europe - Wikipedia                      |                         /wiki/Southern_Europe                          |
# |                          India - Wikipedia                           |                              /wiki/India                               |
# |                      Chess variant - Wikipedia                       |                          /wiki/Chess_variant                           |
# |                         Xiangqi - Wikipedia                          |                             /wiki/Xiangqi                              |
# |                  Abstract strategy game - Wikipedia                  |                      /wiki/Abstract_strategy_game                      |
# |                   Perfect information - Wikipedia                    |                       /wiki/Perfect_information                        |
# |                        Chessboard - Wikipedia                        |                            /wiki/Chessboard                            |
# |                       Chess piece - Wikipedia                        |                           /wiki/Chess_piece                            |
# |                       King (chess) - Wikipedia                       |                           /wiki/King_(chess)                           |
# |                      Queen (chess) - Wikipedia                       |                          /wiki/Queen_(chess)                           |
# |                       Rook (chess) - Wikipedia                       |                           /wiki/Rook_(chess)                           |
# |                      Knight (chess) - Wikipedia                      |                          /wiki/Knight_(chess)                          |
# |                      Bishop (chess) - Wikipedia                      |                          /wiki/Bishop_(chess)                          |
# |                       Pawn (chess) - Wikipedia                       |                           /wiki/Pawn_(chess)                           |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                      Check (chess) - Wikipedia                       |                          /wiki/Check_(chess)                           |
# |                       Draw (chess) - Wikipedia                       |                           /wiki/Draw_(chess)                           |
# |                           FIDE - Wikipedia                           |                               /wiki/FIDE                               |
# |                 World Chess Championship - Wikipedia                 |                       /wiki/World_Chess_Champion                       |
# |                     Wilhelm Steinitz - Wikipedia                     |                         /wiki/Wilhelm_Steinitz                         |
# |                      Magnus Carlsen - Wikipedia                      |                          /wiki/Magnus_Carlsen                          |
# |                       Chess theory - Wikipedia                       |                           /wiki/Chess_theory                           |
# |                           Art - Wikipedia                            |                               /wiki/Art                                |
# |                      Chess problem - Wikipedia                       |                        /wiki/Chess_composition                         |
# |                     Western culture - Wikipedia                      |                         /wiki/Western_culture                          |
# |                       Mathematics - Wikipedia                        |                           /wiki/Mathematics                            |
# |                     Computer science - Wikipedia                     |                         /wiki/Computer_science                         |
# |                        Psychology - Wikipedia                        |                            /wiki/Psychology                            |
# |                     Computer science - Wikipedia                     |                         /wiki/Computer_science                         |
# |                      Computer chess - Wikipedia                      |                          /wiki/Computer_chess                          |
# |                Deep Blue (chess computer) - Wikipedia                |                    /wiki/Deep_Blue_(chess_computer)                    |
# |             Deep Blue versus Garry Kasparov - Wikipedia              |                 /wiki/Deep_Blue_versus_Garry_Kasparov                  |
# |                      Garry Kasparov - Wikipedia                      |                          /wiki/Garry_Kasparov                          |
# |                       Chess engine - Wikipedia                       |                           /wiki/Chess_engine                           |
# |                      Rules of chess - Wikipedia                      |                          /wiki/Rules_of_chess                          |
# |                           FIDE - Wikipedia                           |                               /wiki/FIDE                               |
# |                       Chess piece - Wikipedia                        |                           /wiki/Chess_piece                            |
# |                 White and Black in chess - Wikipedia                 |                     /wiki/White_and_Black_in_chess                     |
# |                        Chess set - Wikipedia                         |                            /wiki/Chess_set                             |
# |                    Staunton chess set - Wikipedia                    |                        /wiki/Staunton_chess_set                        |
# |                        Chessboard - Wikipedia                        |                            /wiki/Chessboard                            |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#ranks                      |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#files                      |
# |                      Chess diagram - Wikipedia                       |                          /wiki/Chess_diagram                           |
# |                         Castling - Wikipedia                         |                             /wiki/Castling                             |
# |                        En passant - Wikipedia                        |                            /wiki/En_passant                            |
# |                         Zugzwang - Wikipedia                         |                             /wiki/Zugzwang                             |
# |                       King (chess) - Wikipedia                       |                           /wiki/King_(chess)                           |
# |                       Rook (chess) - Wikipedia                       |                           /wiki/Rook_(chess)                           |
# |                      Bishop (chess) - Wikipedia                      |                          /wiki/Bishop_(chess)                          |
# |                      Queen (chess) - Wikipedia                       |                          /wiki/Queen_(chess)                           |
# |                      Knight (chess) - Wikipedia                      |                          /wiki/Knight_(chess)                          |
# |                       Pawn (chess) - Wikipedia                       |                           /wiki/Pawn_(chess)                           |
# |                       King (chess) - Wikipedia                       |                           /wiki/King_(chess)                           |
# |                          Chess - Wikipedia                           |                    /wiki/Chess#Check_and_checkmate                     |
# |                       Rook (chess) - Wikipedia                       |                           /wiki/Rook_(chess)                           |
# |                      Bishop (chess) - Wikipedia                      |                          /wiki/Bishop_(chess)                          |
# |                      Queen (chess) - Wikipedia                       |                          /wiki/Queen_(chess)                           |
# |                      Knight (chess) - Wikipedia                      |                          /wiki/Knight_(chess)                          |
# |                       Pawn (chess) - Wikipedia                       |                           /wiki/Pawn_(chess)                           |
# |                      Check (chess) - Wikipedia                       |                          /wiki/Check_(chess)                           |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                      Check (chess) - Wikipedia                       |                          /wiki/Check_(chess)                           |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                         Castling - Wikipedia                         |                             /wiki/Castling                             |
# |                         Castling - Wikipedia                         |                             /wiki/Castling                             |
# |                         Castling - Wikipedia                         |                             /wiki/Castling                             |
# |                        En passant - Wikipedia                        |                            /wiki/En_passant                            |
# |                    Promotion (chess) - Wikipedia                     |                        /wiki/Promotion_(chess)                         |
# |                        En passant - Wikipedia                        |                            /wiki/En_passant                            |
# |                    Promotion (chess) - Wikipedia                     |                        /wiki/Promotion_(chess)                         |
# |                    Glossary of chess - Wikipedia                     |                           /wiki/Rank_(chess)                           |
# |                    Promotion (chess) - Wikipedia                     |                          /wiki/Underpromotion                          |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                          Chess - Wikipedia                           |                    /wiki/Chess#Check_and_checkmate                     |
# |                      Rules of chess - Wikipedia                      |                     /wiki/Rules_of_chess#Resigning                     |
# |                    Glossary of chess - Wikipedia                     |                   /wiki/Glossary_of_chess#Flag_Fall                    |
# |                       Time control - Wikipedia                       |                           /wiki/Time_control                           |
# |                       Draw (chess) - Wikipedia                       |                           /wiki/Draw_(chess)                           |
# |                        Stalemate - Wikipedia                         |                            /wiki/Stalemate                             |
# |                        Stalemate - Wikipedia                         |                            /wiki/Stalemate                             |
# |                    Glossary of chess - Wikipedia                     |                 /wiki/Glossary_of_chess#Dead_position                  |
# |                      Chess endgame - Wikipedia                       |               /wiki/Chess_endgame#King_and_pawn_endings                |
# |                    Draw by agreement - Wikipedia                     |                        /wiki/Draw_by_agreement                         |
# |                   Threefold repetition - Wikipedia                   |                       /wiki/Threefold_repetition                       |
# |                   Threefold repetition - Wikipedia                   |                       /wiki/Fivefold_repetition                        |
# |                     Perpetual check - Wikipedia                      |                         /wiki/Perpetual_check                          |
# |                     Fifty-move rule - Wikipedia                      |                         /wiki/Fifty-move_rule                          |
# |                     Fifty-move rule - Wikipedia                      |                      /wiki/Seventy-five-move_rule                      |
# |                   Two knights endgame - Wikipedia                    |                       /wiki/Two_knights_endgame                        |
# |                  Pawnless chess endgame - Wikipedia                  |                      /wiki/Pawnless_chess_endgame                      |
# |                   Correspondence chess - Wikipedia                   |                       /wiki/Correspondence_chess                       |
# |                       Time control - Wikipedia                       |                           /wiki/Time_control                           |
# |                        Stalemate - Wikipedia                         |                            /wiki/Stalemate                             |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                       Time control - Wikipedia                       |                           /wiki/Time_control                           |
# |                    Glossary of chess - Wikipedia                     |             /wiki/Glossary_of_chess#insufficient_material              |
# |                   Adjournment (games) - Wikipedia                    |                       /wiki/Adjournment_(chess)                        |
# |                        Fast chess - Wikipedia                        |                           /wiki/Bullet_chess                           |
# |                        Fast chess - Wikipedia                        |                           /wiki/Rapid_chess                            |
# |                       Chess clock - Wikipedia                        |                           /wiki/Chess_clock                            |
# |                       Time control - Wikipedia                       |             /wiki/Time_control#Increment_and_delay_methods             |
# |                      Chess notation - Wikipedia                      |                          /wiki/Chess_notation                          |
# |                Algebraic notation (chess) - Wikipedia                |                    /wiki/Algebraic_notation_(chess)                    |
# |                Algebraic notation (chess) - Wikipedia                |           /wiki/Algebraic_notation_(chess)#Naming_the_pieces           |
# |                Algebraic notation (chess) - Wikipedia                |                    /wiki/Algebraic_notation_(chess)                    |
# |                    Glossary of chess - Wikipedia                     |                    /wiki/Glossary_of_chess#kingside                    |
# |                    Glossary of chess - Wikipedia                     |                   /wiki/Glossary_of_chess#queenside                    |
# |                    Discovered attack - Wikipedia                     |                         /wiki/Discovered_check                         |
# |                       Double check - Wikipedia                       |                           /wiki/Double_check                           |
# |                 Chess annotation symbols - Wikipedia                 |                       /wiki/Punctuation_(chess)                        |
# |                      Scholar's mate - Wikipedia                      |                         /wiki/Scholar%27s_mate                         |
# |                      Scholar's mate - Wikipedia                      |                         /wiki/Scholar%27s_mate                         |
# |                 Chess annotation symbols - Wikipedia                 |                   /wiki/Chess_annotation_symbols#?!                    |
# |                 Chess annotation symbols - Wikipedia                 |                   /wiki/Chess_annotation_symbols#??                    |
# |                Algebraic notation (chess) - Wikipedia                |                   /wiki/Algebraic_notation_(chess)##                   |
# |                  Portable Game Notation - Wikipedia                  |                      /wiki/Portable_Game_Notation                      |
# |                     Markup language - Wikipedia                      |                         /wiki/Markup_language                          |
# |                   Descriptive notation - Wikipedia                   |                       /wiki/Descriptive_notation                       |
# |                  ICCF numeric notation - Wikipedia                   |                      /wiki/ICCF_numeric_notation                       |
# |      International Correspondence Chess Federation - Wikipedia       |          /wiki/International_Correspondence_Chess_Federation           |
# |               Tata Steel Chess Tournament - Wikipedia                |                   /wiki/Tata_Steel_Chess_Tournament                    |
# |                         Congress - Wikipedia                         |                             /wiki/Congress                             |
# |                  Round-robin tournament - Wikipedia                  |                      /wiki/Round-robin_tournament                      |
# |                 Swiss-system tournament - Wikipedia                  |                     /wiki/Swiss_system_tournament                      |
# |                      Chess scoring - Wikipedia                       |                          /wiki/Chess_scoring                           |
# |                          Kotka - Wikipedia                           |                              /wiki/Kotka                               |
# |                         Finland - Wikipedia                          |                             /wiki/Finland                              |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#match                      |
# |                           FIDE - Wikipedia                           |                               /wiki/FIDE                               |
# |                     French language - Wikipedia                      |                         /wiki/French_language                          |
# |         International Braille Chess Association - Wikipedia          |             /wiki/International_Braille_Chess_Association              |
# |                  Sports governing body - Wikipedia                   |                      /wiki/Sports_governing_body                       |
# |             International Olympic Committee - Wikipedia              |                 /wiki/International_Olympic_Committee                  |
# |                      Olympic Games - Wikipedia                       |                          /wiki/Olympic_Games                           |
# |                      Garry Kasparov - Wikipedia                      |                          /wiki/Garry_Kasparov                          |
# |                 World Chess Championship - Wikipedia                 |                     /wiki/World_Chess_Championship                     |
# |                      Magnus Carlsen - Wikipedia                      |                          /wiki/Magnus_Carlsen                          |
# |                        Ju Wenjun - Wikipedia                         |                            /wiki/Ju_Wenjun                             |
# |             World Junior Chess Championship - Wikipedia              |                 /wiki/World_Junior_Chess_Championship                  |
# |          European Individual Chess Championship - Wikipedia          |              /wiki/European_Individual_Chess_Championship              |
# |                    Geography of chess - Wikipedia                    |               /wiki/List_of_national_chess_championships               |
# |          Linares International Chess Tournament - Wikipedia          |                     /wiki/Linares_chess_tournament                     |
# |                  Amber chess tournament - Wikipedia                  |                           /wiki/Melody_Amber                           |
# |            Dortmund Sparkassen Chess Meeting - Wikipedia             |                /wiki/Dortmund_Sparkassen_Chess_Meeting                 |
# |                      M-Tel Masters - Wikipedia                       |                          /wiki/M-tel_Masters                           |
# |               Tata Steel Chess Tournament - Wikipedia                |                   /wiki/Tata_Steel_Chess_Tournament                    |
# |                      Chess Olympiad - Wikipedia                      |                          /wiki/Chess_Olympiad                          |
# |             European Team Chess Championship - Wikipedia             |                 /wiki/European_Team_Chess_Championship                 |
# |             World Chess Solving Championship - Wikipedia             |                 /wiki/World_Chess_Solving_Championship                 |
# |                   Correspondence chess - Wikipedia                   |                       /wiki/Correspondence_Chess                       |
# |                       Chess title - Wikipedia                        |                           /wiki/Chess_titles                           |
# |      International Correspondence Chess Federation - Wikipedia       |          /wiki/International_Correspondence_Chess_Federation           |
# |                    Elo rating system - Wikipedia                     |                        /wiki/Elo_rating_system                         |
# |                        Arpad Elo - Wikipedia                         |                            /wiki/Arpad_Elo                             |
# |                      Magnus Carlsen - Wikipedia                      |                          /wiki/Magnus_Carlsen                          |
# |                   Grandmaster (chess) - Wikipedia                    |                       /wiki/Grandmaster_(chess)                        |
# |                       FIDE titles - Wikipedia                        |                       /wiki/International_Master                       |
# |                       FIDE titles - Wikipedia                        |                           /wiki/FIDE_Master                            |
# |                       FIDE titles - Wikipedia                        |                         /wiki/Candidate_Master                         |
# |                   Nona Gaprindashvili - Wikipedia                    |                       /wiki/Nona_Gaprindashvili                        |
# |      International Correspondence Chess Federation - Wikipedia       |          /wiki/International_Correspondence_Chess_Federation           |
# |                       Chess theory - Wikipedia                       |                           /wiki/Chess_theory                           |
# |                       Chess tactic - Wikipedia                       |                          /wiki/Chess_tactics                           |
# |                      Chess strategy - Wikipedia                      |                          /wiki/Chess_strategy                          |
# |                     Chess libraries - Wikipedia                      |                         /wiki/Chess_libraries                          |
# |                   List of chess books - Wikipedia                    |                       /wiki/List_of_chess_books                        |
# |                List of chess periodicals - Wikipedia                 |                    /wiki/List_of_chess_periodicals                     |
# |                     H. J. R. Murray - Wikipedia                      |                          /wiki/H.J.R._Murray                           |
# |               Chess columns in newspapers - Wikipedia                |                   /wiki/Chess_columns_in_newspapers                    |
# |                    Baruch Harold Wood - Wikipedia                    |                        /wiki/Baruch_Harold_Wood                        |
# |                   David Vincent Hooper - Wikipedia                   |                   /wiki/David_Hooper_(chess_player)                    |
# |                        Ken Whyld - Wikipedia                         |                          /wiki/Kenneth_Whyld                           |
# |                 Cleveland Public Library - Wikipedia                 |                     /wiki/Cleveland_Public_Library                     |
# |             Royal Library of the Netherlands - Wikipedia             |               /wiki/National_Library_of_the_Netherlands                |
# |              The Oxford Companion to Chess - Wikipedia               |                  /wiki/The_Oxford_Companion_to_Chess                   |
# |                       Chess tactic - Wikipedia                       |                          /wiki/Chess_tactics                           |
# |                      Chess strategy - Wikipedia                      |                          /wiki/Chess_strategy                          |
# |                      Chess opening - Wikipedia                       |                          /wiki/Chess_opening                           |
# |                        Ruy Lopez - Wikipedia                         |                            /wiki/Ruy_Lopez                             |
# |                     Sicilian Defence - Wikipedia                     |                         /wiki/Sicilian_Defense                         |
# |             Encyclopaedia of Chess Openings - Wikipedia              |                 /wiki/Encyclopaedia_of_Chess_Openings                  |
# |                    Glossary of chess - Wikipedia                     |                /wiki/Glossary_of_chess#positional_play                 |
# |                       Réti Opening - Wikipedia                       |                        /wiki/R%C3%A9ti_Opening                         |
# |                      Latvian Gambit - Wikipedia                      |                          /wiki/Latvian_Gambit                          |
# |                       Chess theory - Wikipedia                       |                       /wiki/Chess_opening_theory                       |
# |                    Glossary of chess - Wikipedia                     |                    /wiki/Glossary_of_chess#develop                     |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#center                     |
# |                      Pawn structure - Wikipedia                      |                          /wiki/Pawn_structure                          |
# |                       Chess theory - Wikipedia                       |                           /wiki/Chess_theory                           |
# |              First-move advantage in chess - Wikipedia               |                  /wiki/First-move_advantage_in_chess                   |
# |                    Initiative (chess) - Wikipedia                    |                        /wiki/Initiative_(chess)                        |
# |                    Glossary of chess - Wikipedia                     |                    /wiki/Glossary_of_chess#equality                    |
# |                    Glossary of chess - Wikipedia                     |                    /wiki/Glossary_of_chess#dynamism                    |
# |                    Glossary of chess - Wikipedia                     |                  /wiki/Glossary_of_chess#counterplay                   |
# |                     Chess middlegame - Wikipedia                     |                         /wiki/Chess_middlegame                         |
# |                      Chess endgame - Wikipedia                       |              /wiki/Chess_endgame#The_start_of_the_endgame              |
# |                   Combination (chess) - Wikipedia                    |                       /wiki/Combination_(chess)                        |
# |                       Boden's Mate - Wikipedia                       |                          /wiki/Boden%27s_Mate                          |
# |           Lasker versus Bauer, Amsterdam, 1889 - Wikipedia           |                 /wiki/Lasker_-_Bauer,_Amsterdam,_1889                  |
# |                    Glossary of chess - Wikipedia                     |                /wiki/Glossary_of_chess#minority_attack                 |
# |                    Glossary of chess - Wikipedia                     |                 /wiki/Glossary_of_chess#simplification                 |
# |                      Chess endgame - Wikipedia                       |              /wiki/Chess_endgame#Bishop_and_pawn_endings               |
# |             Opposite-colored bishops endgame - Wikipedia             |                 /wiki/Opposite-colored_bishops_endgame                 |
# |                       Chess tactic - Wikipedia                       |                          /wiki/Chess_tactics                           |
# |                    Glossary of chess - Wikipedia                     |                   /wiki/Glossary_of_chess#quiet_move                   |
# |                    Glossary of chess - Wikipedia                     |                  /wiki/Glossary_of_chess#forced_move                   |
# |                       Pin (chess) - Wikipedia                        |                           /wiki/Pin_(chess)                            |
# |                       Fork (chess) - Wikipedia                       |                           /wiki/Fork_(chess)                           |
# |                      Skewer (chess) - Wikipedia                      |                          /wiki/Skewer_(chess)                          |
# |                     Battery (chess) - Wikipedia                      |                         /wiki/Battery_(chess)                          |
# |                    Discovered attack - Wikipedia                     |                        /wiki/Discovered_attack                         |
# |                       Zwischenzug - Wikipedia                        |                           /wiki/Zwischenzug                            |
# |                    Deflection (chess) - Wikipedia                    |                        /wiki/Deflection_(chess)                        |
# |                      Decoy (chess) - Wikipedia                       |                          /wiki/Decoy_(chess)                           |
# |                    Sacrifice (chess) - Wikipedia                     |                        /wiki/Sacrifice_(chess)                         |
# |                   Undermining (chess) - Wikipedia                    |                       /wiki/Undermining_(chess)                        |
# |                   Overloading (chess) - Wikipedia                    |                       /wiki/Overloading_(chess)                        |
# |                   Interference (chess) - Wikipedia                   |                       /wiki/Interference_(chess)                       |
# |                    Glossary of chess - Wikipedia                     |                    /wiki/Glossary_of_chess#material                    |
# |                   Combination (chess) - Wikipedia                    |                       /wiki/Combination_(chess)                        |
# |                      Immortal Game - Wikipedia                       |                          /wiki/Immortal_Game                           |
# |                      Chess strategy - Wikipedia                      |                          /wiki/Chess_strategy                          |
# |                      Pawn structure - Wikipedia                      |                          /wiki/Pawn_structure                          |
# |                        Key square - Wikipedia                        |                            /wiki/Key_square                            |
# |                Chess piece relative value - Wikipedia                |                    /wiki/Chess_piece_relative_value                    |
# |                   The exchange (chess) - Wikipedia                   |                       /wiki/The_exchange_(chess)                       |
# |                    Glossary of chess - Wikipedia                     |                  /wiki/Glossary_of_chess#closed_game                   |
# |                    Glossary of chess - Wikipedia                     |                   /wiki/Glossary_of_chess#open_game                    |
# |                      Pawn structure - Wikipedia                      |                          /wiki/Pawn_structure                          |
# |                      Isolated pawn - Wikipedia                       |                          /wiki/Isolated_pawn                           |
# |                      Doubled pawns - Wikipedia                       |                          /wiki/Doubled_pawns                           |
# |                      Backward pawn - Wikipedia                       |                          /wiki/Backward_pawn                           |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#holes                      |
# |                         Zugzwang - Wikipedia                         |                             /wiki/Zugzwang                             |
# |                      Chess endgame - Wikipedia                       |                          /wiki/Chess_endgame                           |
# |                    Promotion (chess) - Wikipedia                     |                        /wiki/Promotion_(chess)                         |
# |                    Glossary of chess - Wikipedia                     |                      /wiki/Glossary_of_chess#rank                      |
# |                    Glossary of chess - Wikipedia                     |                     /wiki/Glossary_of_chess#center                     |
# |                         Zugzwang - Wikipedia                         |                             /wiki/Zugzwang                             |
# |                        Stalemate - Wikipedia                         |                            /wiki/Stalemate                             |
# |                        Checkmate - Wikipedia                         |                    /wiki/Checkmate#Basic_checkmates                    |
# |                      Chess endgame - Wikipedia                       |                      /wiki/King_and_pawn_endgame                       |
# |            Rook and pawn versus rook endgame - Wikipedia             |                    /wiki/Rook_and_pawn_versus_rook                     |
# |                     History of chess - Wikipedia                     |                         /wiki/History_of_chess                         |
# |                     Sasanian Empire - Wikipedia                      |                         /wiki/Sasanian_Empire                          |
# |                        Khosrow I - Wikipedia                         |                            /wiki/Khosrow_I                             |
# |                     Maukhari dynasty - Wikipedia                     |                             /wiki/Maukhari                             |
# |                       Sharvavarman - Wikipedia                       |                         /wiki/%C5%9Aarvavarman                         |
# |                         Kannauj - Wikipedia                          |                             /wiki/Kannauj                              |
# |                        Shahnameh - Wikipedia                         |                             /wiki/Shahnama                             |
# |                      Middle Persian - Wikipedia                      |                          /wiki/Middle_Persian                          |
# |                      Harshacharita - Wikipedia                       |                          /wiki/Harshacharita                           |
# |                         Sanskrit - Wikipedia                         |                             /wiki/Sanskrit                             |
# |                        Bozorgmehr - Wikipedia                        |                            /wiki/Bozorgmehr                            |
# |                        Khosrow I - Wikipedia                         |                            /wiki/Khosrow_I                             |
# |                         Al-Adli - Wikipedia                          |                         /wiki/Al-Adli_ar-Rumi                          |
# |                     Kalīla wa-Dimna - Wikipedia                      |                       /wiki/Kal%C4%ABla_wa-Dimna                       |
# |                          India - Wikipedia                           |                              /wiki/India                               |
# |                        Chaturanga - Wikipedia                        |                            /wiki/Chaturanga                            |
# |                         Sanskrit - Wikipedia                         |                        /wiki/Sanskrit_language                         |
# |                         Infantry - Wikipedia                         |                             /wiki/Infantry                             |
# |                         Cavalry - Wikipedia                          |                             /wiki/Cavalry                              |
# |                       War elephant - Wikipedia                       |                           /wiki/War_elephant                           |
# |                         Chariot - Wikipedia                          |                             /wiki/Chariot                              |
# |                        Ashtapada - Wikipedia                         |                            /wiki/Ashtapada                             |
# |                        Silk Road - Wikipedia                         |                            /wiki/Silk_Road                             |
# |                     Sasanian Empire - Wikipedia                      |                         /wiki/Sasanian_Persia                          |
# |                         Shatranj - Wikipedia                         |                             /wiki/Chatrang                             |
# |                       Muslim world - Wikipedia                       |                           /wiki/Muslim_world                           |
# |                Muslim conquest of Persia - Wikipedia                 |                    /wiki/Islamic_conquest_of_Persia                    |
# |                         Shatranj - Wikipedia                         |                             /wiki/Shatranj                             |
# |                   Portuguese language - Wikipedia                    |                       /wiki/Portuguese_language                        |
# |                      Greek language - Wikipedia                      |                          /wiki/Greek_language                          |
# |                        Checkmate - Wikipedia                         |                            /wiki/Checkmate                             |
# |                     Knights Templar - Wikipedia                      |                         /wiki/Knights_Templar                          |
# |                   Libro de los Juegos - Wikipedia                    |                       /wiki/Libro_de_los_juegos                        |
# |                         Xiangqi - Wikipedia                          |                             /wiki/Xiangqi                              |
# |                  Afrasiyab (Samarkand) - Wikipedia                   |                      /wiki/Afrasiyab_(Samarkand)                       |
# |                        Samarkand - Wikipedia                         |                            /wiki/Samarkand                             |
# |                        Uzbekistan - Wikipedia                        |                            /wiki/Uzbekistan                            |
# |                       Transoxiana - Wikipedia                        |                           /wiki/Transoxiana                            |
# |                          Sogdia - Wikipedia                          |                             /wiki/Sogdiana                             |
# |                         Bactria - Wikipedia                          |                             /wiki/Bactria                              |
# |                         Gandhara - Wikipedia                         |                             /wiki/Gandhara                             |
# |                         Kashmir - Wikipedia                          |                             /wiki/Kashmir                              |
# |                        Al-Andalus - Wikipedia                        |                            /wiki/Al_Andalus                            |
# |                Latin Catholics of Malabar - Wikipedia                |                        /wiki/Latin_Christianity                        |
# |                    Versus de scachis - Wikipedia                     |                        /wiki/Versus_de_scachis                         |
# |                     Einsiedeln Abbey - Wikipedia                     |                         /wiki/Einsiedeln_Abbey                         |
# |                        Backgammon - Wikipedia                        |                            /wiki/Backgammon                            |
# |                           Dice - Wikipedia                           |                               /wiki/Dice                               |
# |                   Libro de los Juegos - Wikipedia                    |                       /wiki/Libro_de_los_juegos                        |
# |                         Shatranj - Wikipedia                         |                             /wiki/Shatranj                             |
# |                      Wazir (chess) - Wikipedia                       |                          /wiki/Wazir_(chess)                           |
# |                  Luis Ramírez de Lucena - Wikipedia                  |                   /wiki/Luis_Ram%C3%ADrez_de_Lucena                    |
# |                      Queen (chess) - Wikipedia                       |                          /wiki/Queen_(chess)                           |
# |                          Vizier - Wikipedia                          |                    /wiki/Vizier#Influence_on_chess                     |
# |                       Chess theory - Wikipedia                       |                           /wiki/Chess_theory                           |
# |                        Spaniards - Wikipedia                         |                          /wiki/Spanish_people                          |
# |                  Luis Ramírez de Lucena - Wikipedia                  |                   /wiki/Luis_Ram%C3%ADrez_de_Lucena                    |
# |                        Salamanca - Wikipedia                         |                            /wiki/Salamanca                             |
# |                      Pedro Damiano - Wikipedia                       |                          /wiki/Pedro_Damiano                           |
# |                Giovanni Leonardo Di Bona - Wikipedia                 |                    /wiki/Giovanni_Leonardo_Di_Bona                     |
# |                  Giulio Cesare Polerio - Wikipedia                   |                      /wiki/Giulio_Cesare_Polerio                       |
# |                     Gioachino Greco - Wikipedia                      |                         /wiki/Gioachino_Greco                          |
# |                   Ruy López de Segura - Wikipedia                    |                     /wiki/Ruy_L%C3%B3pez_de_Segura                     |
# |                      Immortal Game - Wikipedia                       |                          /wiki/Immortal_Game                           |
# |             François-André Danican Philidor - Wikipedia              |            /wiki/Fran%C3%A7ois-Andr%C3%A9_Danican_Philidor             |
# ...
# |                    Progressive chess - Wikipedia                     |                        /wiki/Progressive_chess                         |
# |                  List of chess variants - Wikipedia                  |                        /wiki/Three-check_chess                         |
# |                  List of chess variants - Wikipedia                  |                        /wiki/Way_of_the_Knight                         |
# |                     Avalanche chess - Wikipedia                      |                         /wiki/Avalanche_chess                          |
# |                      Kung-Fu Chess - Wikipedia                       |                          /wiki/Kung-Fu_Chess                           |
# |                    Marseillais chess - Wikipedia                     |                        /wiki/Marseillais_chess                         |
# |                      Monster chess - Wikipedia                       |                          /wiki/Monster_chess                           |
# |                    Progressive chess - Wikipedia                     |                        /wiki/Progressive_chess                         |
# |                        Dark chess - Wikipedia                        |                            /wiki/Dark_chess                            |
# |                        Dice chess - Wikipedia                        |                            /wiki/Dice_chess                            |
# |                     Knightmare Chess - Wikipedia                     |                         /wiki/Knightmare_Chess                         |
# |                    Kriegspiel (chess) - Wikipedia                    |                        /wiki/Kriegspiel_(chess)                        |
# |                        Penultima - Wikipedia                         |                            /wiki/Penultima                             |
# |                       Alice chess - Wikipedia                        |                           /wiki/Alice_chess                            |
# |                Apocalypse (chess variant) - Wikipedia                |                    /wiki/Apocalypse_(chess_variant)                    |
# |                   Chad (chess variant) - Wikipedia                   |                       /wiki/Chad_(chess_variant)                       |
# |                        Chessence - Wikipedia                         |                            /wiki/Chessence                             |
# |                  Congo (chess variant) - Wikipedia                   |                      /wiki/Congo_(chess_variant)                       |
# |                      Diplomat chess - Wikipedia                      |                          /wiki/Diplomat_chess                          |
# |                Dragonfly (chess variant) - Wikipedia                 |                    /wiki/Dragonfly_(chess_variant)                     |
# |                        Jeson Mor - Wikipedia                         |                            /wiki/Jeson_Mor                             |
# |                  Parallel worlds chess - Wikipedia                   |                      /wiki/Parallel_worlds_chess                       |
# |                Rollerball (chess variant) - Wikipedia                |                    /wiki/Rollerball_(chess_variant)                    |
# |           5D Chess with Multiverse Time Travel - Wikipedia           |               /wiki/5D_Chess_with_Multiverse_Time_Travel               |
# |                      Baroque chess - Wikipedia                       |                          /wiki/Baroque_chess                           |
# |                      Berolina chess - Wikipedia                      |                          /wiki/Berolina_chess                          |
# |                  Chakra (chess variant) - Wikipedia                  |                      /wiki/Chakra_(chess_variant)                      |
# |               Chess with different armies - Wikipedia                |                   /wiki/Chess_with_different_armies                    |
# |                       Duell (game) - Wikipedia                       |                          /wiki/Duell_(chess)                           |
# |                   Falcon–hunter chess - Wikipedia                    |                   /wiki/Falcon%E2%80%93hunter_chess                    |
# |                    Grasshopper chess - Wikipedia                     |                        /wiki/Grasshopper_chess                         |
# |                  List of chess variants - Wikipedia                  |                         /wiki/Musketeer_chess                          |
# |                  Pocket mutation chess - Wikipedia                   |                      /wiki/Pocket_mutation_chess                       |
# |                       Almost chess - Wikipedia                       |                           /wiki/Almost_chess                           |
# |                     Capablanca chess - Wikipedia                     |                          /wiki/Bird%27s_chess                          |
# |                     Capablanca chess - Wikipedia                     |                         /wiki/Capablanca_chess                         |
# |                 Capablanca random chess - Wikipedia                  |                     /wiki/Capablanca_random_chess                      |
# |                     Chancellor chess - Wikipedia                     |                         /wiki/Chancellor_chess                         |
# |                  List of chess variants - Wikipedia                  |                          /wiki/Embassy_chess                           |
# |                     Capablanca chess - Wikipedia                     |                           /wiki/Gothic_chess                           |
# |                       Grand chess - Wikipedia                        |                           /wiki/Grand_chess                            |
# |                       Janus Chess - Wikipedia                        |                           /wiki/Janus_chess                            |
# |                 Maharajah and the Sepoys - Wikipedia                 |                     /wiki/Maharajah_and_the_Sepoys                     |
# |                       Modern chess - Wikipedia                       |                           /wiki/Modern_chess                           |
# |                     Yasser Seirawan - Wikipedia                      |                          /wiki/Seirawan_chess                          |
# |                    Tutti-frutti chess - Wikipedia                    |                        /wiki/Tutti-Frutti_chess                        |
# |                       Chesquerque - Wikipedia                        |                           /wiki/Chesquerque                            |
# |               Chess on a really big board - Wikipedia                |                   /wiki/Chess_on_a_really_big_board                    |
# |                      Courier chess - Wikipedia                       |                          /wiki/Courier-Spiel                           |
# |                       Dragonchess - Wikipedia                        |                           /wiki/Dragonchess                            |
# |                           Gess - Wikipedia                           |                               /wiki/Gess                               |
# |                       Omega Chess - Wikipedia                        |                           /wiki/Omega_chess                            |
# |                        Stratomic - Wikipedia                         |                            /wiki/Stratomic                             |
# |                 Triangular chess (game) - Wikipedia                  |                     /wiki/Triangular_chess_(game)                      |
# |                2000 A.D. (chess variant) - Wikipedia                 |                    /wiki/2000_A.D._(chess_variant)                     |
# |                     Wildebeest chess - Wikipedia                     |                         /wiki/Wildebeest_chess                         |
# |                        Wolf chess - Wikipedia                        |                            /wiki/Wolf_chess                            |
# |                  List of chess variants - Wikipedia                  |                        /wiki/Multiplayer_chess                         |
# |                     Bosworth (game) - Wikipedia                      |                         /wiki/Bosworth_(game)                          |
# |                      Bughouse chess - Wikipedia                      |                          /wiki/Bughouse_chess                          |
# |                      Business chess - Wikipedia                      |                          /wiki/Business_chess                          |
# |                          Djambi - Wikipedia                          |                              /wiki/Djambi                              |
# |                      Enochian chess - Wikipedia                      |                          /wiki/Enochian_chess                          |
# |                         Forchess - Wikipedia                         |                             /wiki/Forchess                             |
# |                      Fortress chess - Wikipedia                      |                          /wiki/Fortress_chess                          |
# |                    Four-player chess - Wikipedia                     |                        /wiki/Four-player_chess                         |
# |                         Mak-yek - Wikipedia                          |                           /wiki/Mak-yek#Gala                           |
# |                       Quatrochess - Wikipedia                        |                           /wiki/Quatrochess                            |
# |                     Three-man chess - Wikipedia                      |                         /wiki/Three-man_chess                          |
# |                    Three-player chess - Wikipedia                    |                        /wiki/Three-player_chess                        |
# |                        Tri-chess - Wikipedia                         |                            /wiki/Tri-chess                             |
# |                          Arimaa - Wikipedia                          |                              /wiki/Arimaa                              |
# |                          Jetan - Wikipedia                           |                              /wiki/Jetan                               |
# |                      Martian chess - Wikipedia                       |                          /wiki/Martian_chess                           |
# |                       Navia Dratp - Wikipedia                        |                           /wiki/Navia_Dratp                            |
# |                  The Duke (board game) - Wikipedia                   |                      /wiki/The_Duke_(board_game)                       |
# |                        Chaturaji - Wikipedia                         |                            /wiki/Chaturaji                             |
# |                      Courier chess - Wikipedia                       |                          /wiki/Courier_chess                           |
# |                      Grant Acedrex - Wikipedia                       |                          /wiki/Grant_Acedrex                           |
# |                         Shatranj - Wikipedia                         |                             /wiki/Shatranj                             |
# |                       Short assize - Wikipedia                       |                           /wiki/Short_assize                           |
# |                     Tamerlane chess - Wikipedia                      |                         /wiki/Tamerlane_chess                          |
# |                          Banqi - Wikipedia                           |                              /wiki/Banqi                               |
# |                Game of the Three Kingdoms - Wikipedia                |                    /wiki/Game_of_the_Three_Kingdoms                    |
# |                        Hiashatar - Wikipedia                         |                            /wiki/Hiashatar                             |
# |                          Janggi - Wikipedia                          |                              /wiki/Janggi                              |
# |                   Jungle (board game) - Wikipedia                    |                       /wiki/Jungle_(board_game)                        |
# |                          Makruk - Wikipedia                          |                   /wiki/Ouk-Khmer_(Hill%27s_version)                   |
# |                          Makruk - Wikipedia                          |                              /wiki/Makruk                              |
# |                       Manchu chess - Wikipedia                       |                           /wiki/Manchu_chess                           |
# |                         Senterej - Wikipedia                         |                             /wiki/Senterej                             |
# |                          Shatar - Wikipedia                          |                              /wiki/Shatar                              |
# |                          Shogi - Wikipedia                           |                              /wiki/Shogi                               |
# |                         Sittuyin - Wikipedia                         |                             /wiki/Sittuyin                             |
# |                         Xiangqi - Wikipedia                          |                             /wiki/Xiangqi                              |
# |                          ChessV - Wikipedia                          |                              /wiki/ChessV                              |
# |                        Fairy-Max - Wikipedia                         |                            /wiki/Fairy-Max                             |
# |                          XBoard - Wikipedia                          |                              /wiki/XBoard                              |
# |                    Zillions of Games - Wikipedia                     |                        /wiki/Zillions_of_Games                         |
# |                   Correspondence chess - Wikipedia                   |                       /wiki/Correspondence_chess                       |
# |                       Fairy chess - Wikipedia                        |                           /wiki/Fairy_chess                            |
# |                    Fairy chess piece - Wikipedia                     |                        /wiki/Fairy_chess_piece                         |
# |                    Fairy Chess Review - Wikipedia                    |                        /wiki/Fairy_Chess_Review                        |
# |                 The Chess Variant Pages - Wikipedia                  |                     /wiki/The_Chess_Variant_Pages                      |
# |                          Chess - Wikipedia                           |                              /wiki/Chess                               |
# |                          Chess - Wikipedia                           |                              /wiki/Chess                               |
# |                   Wikipedia, the free encyclopedia                   |                            /wiki/Main_Page                             |
# |                   Wikipedia, the free encyclopedia                   |                            /wiki/Main_Page                             |
# +----------------------------------------------------------------------+------------------------------------------------------------------------+
